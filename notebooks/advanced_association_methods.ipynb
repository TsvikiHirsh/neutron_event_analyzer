# %% [markdown]
# # Advanced Association Methods
#
# This notebook demonstrates the advanced pixel-to-photon association methods:
#
# 1. **Mystic** - Constrained optimization using the mystic framework
# 2. **ML** - Machine learning trained on constrained associations
#
# Both methods implement the verified EMPIR algorithm:
# - ToT-weighted center of gravity
# - Euclidean distance metric
# - Time window filtering

# %% [markdown]
# ## Setup

# %%
import neutron_event_analyzer as nea
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data
#
# Load a dataset with pixels, photons, and events. Adjust the path to your data folder.

# %%
data_path = "/work/nuclear/PTB/archive/pencilbeam0/fast_neutrons"

assoc = nea.Analyse(
    data_path,
    pixels=True,
    photons=True,
    events=True,
    limit=10000
)
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.

# %% [markdown]
# Check the loaded data:

# %%
assoc.pixels_df.shape, assoc.photons_df.shape, assoc.events_df.shape
# Out:
# ((10000, 5), (600, 4), (517, 6))

# %% [markdown]
# ---
# ## Method 1: Simple Association (Baseline)
#
# The default method uses a forward time-window with ToT-weighted center of gravity matching.

# %%
assoc_simple = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=1000)
assoc_simple.associate(method='simple')
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons:   0%|          | 0/63 [00:00<?, ?it/s]
# Associating photons to events:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-29 15:13:36,722 - Before grouping: 62 photons with non-NaN assoc_x
# 2026-01-29 15:13:36,726 - After grouping: 62 photons with non-NaN assoc_event_id
# ✅ Matched 62 of 63 photons (98.4%)
# ✅ Saved 1000 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 0.09 MB
#    Columns: 18
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">518 / 1,000</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">51.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">61 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">96.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">62 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.4%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">54 / 54</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">4.9%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">63.9%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.1%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_simple.associated_df.head()
# Out:
#     px/x   px/y  px/toa  px/tot  px/tof  ph/id   ph/x    ph/y  ph/toa  \
# 0  134.0  123.0     0.0     1.0     NaN    5.0  132.5  123.28     0.0
# 1  126.0  127.0     0.0     1.0     NaN    3.0  126.0  127.00     0.0
# 2  126.0  126.0     0.0     1.0     NaN    3.0  126.0  127.00     0.0
# 3  127.0  125.0     0.0     7.0     NaN    NaN    NaN     NaN     NaN
# 4  128.0  123.0     0.0     2.0     NaN    NaN    NaN     NaN     NaN
#
#      ph/cog  ev/id   ev/x    ev/y  ev/toa  ev/n  ev/psd  ev/cog  ph/n
# 0  0.547699   36.0  132.5  123.28     0.0   1.0     0.0     0.0    13
# 1  0.870651   25.0  126.0  127.00     0.0   1.0     0.0     0.0     9
# 2  0.870651   25.0  126.0  127.00     0.0   1.0     0.0     0.0     9
# 3       NaN    NaN    NaN     NaN     NaN   NaN     NaN     NaN     0
# 4       NaN    NaN    NaN     NaN     NaN   NaN     NaN     NaN     0

# %% [markdown]
# ---
# ## Method 2: Mystic Optimization
#
# The mystic method formulates association as a constrained optimization problem:
#
# - **Objective**: Minimize CoG distance + time penalty
# - **Constraints**: Minimum pixel count, spatial/temporal bounds
# - **Solver**: Powell's method or differential evolution
#
# This method is slower but can find better associations in ambiguous cases.

# %%
assoc_mystic = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=1000)
assoc_mystic.associate(method='mystic')
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons (mystic):   0%|          | 0/63 [00:00<?, ?it/s]
# ✅ Pixel-Photon Association (mystic optimization):
#    Pixels:  523 / 1,000 matched (52.3%)
#    Photons: 61 / 63 matched (96.8%)
#    Optimization: 60 success, 1 fallback, 0 failed
# Associating photons to events (mystic):   0%|          | 0/54 [00:00<?, ?it/s]
# ✅ Photon-Event Association (mystic optimization):
#    Photons: 62 / 63 matched (98.4%)
#    Events:  54 / 54 matched (100.0%)
#    Optimization: 8 success, 46 fallback, 0 failed
# ✅ Saved 1000 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 0.09 MB
#    Columns: 18
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">523 / 1,000</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">52.3%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">61 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">96.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">62 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.4%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">54 / 54</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">5.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">63.3%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.1%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_mystic.associated_df.head()
# Out:
#     px/x   px/y  px/toa  px/tot  px/tof  ph/id   ph/x    ph/y  ph/toa  \
# 0  134.0  123.0     0.0     1.0     NaN    5.0  132.5  123.28     0.0
# 1  126.0  127.0     0.0     1.0     NaN    3.0  126.0  127.00     0.0
# 2  126.0  126.0     0.0     1.0     NaN    3.0  126.0  127.00     0.0
# 3  127.0  125.0     0.0     7.0     NaN    NaN    NaN     NaN     NaN
# 4  128.0  123.0     0.0     2.0     NaN    NaN    NaN     NaN     NaN
#
#      ph/cog  ev/id   ev/x    ev/y  ev/toa  ev/n  ev/psd  ev/cog  ph/n
# 0  0.547699    1.0  132.5  123.28     0.0   1.0     0.0     0.0    13
# 1  0.870651    6.0  126.0  127.00     0.0   1.0     0.0     0.0     9
# 2  0.870651    6.0  126.0  127.00     0.0   1.0     0.0     0.0     9
# 3       NaN    NaN    NaN     NaN     NaN   NaN     NaN     NaN     0
# 4       NaN    NaN    NaN     NaN     NaN   NaN     NaN     NaN     0

# %% [markdown]
# ---
# ## Method 3: ML-Based Association
#
# The ML method uses a trained classifier to predict pixel-to-photon associations.
#
# ### Step 1: Train the Model
#
# Train on constrained associations from mystic or simple method:

# %%
# Train on mystic-constrained associations
trainer = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=5000)

model = trainer.train_association_model(
    method='simple',      # Use simple/mystic/kdtree for training labels
    model_type='rf',      # rf, gb, mlp, or torch
    n_samples=10000
)
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Generating training data using 'simple' method...
# Generating training data:   0%|          | 0/314 [00:00<?, ?it/s]
# Training rf model on 6,326 samples...
#    Positive samples: 2,275 (36.0%)
#    Negative samples: 4,051 (64.0%)
#    Training accuracy: 84.9%
#    Training F1 score: 0.746

# %% [markdown]
# Available model types:
#
# | Type | Description |
# |------|-------------|
# | `rf` | Random Forest (fast, good default) |
# | `gb` | Gradient Boosting (slower, often better) |
# | `mlp` | Neural Network (sklearn MLP) |
# | `torch` | PyTorch Neural Network |

# %% [markdown]
# ### Step 2: Use the Trained Model

# %%
assoc_ml = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=1000)
assoc_ml._ml_association_model = model
assoc_ml.associate(method='ml')
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons (ML):   0%|          | 0/63 [00:00<?, ?it/s]
# ✅ Pixel-Photon Association (ML):
#    Pixels:  7 / 1,000 matched (0.7%)
#    Photons: 4 / 63 matched (6.3%)
#    ML predictions made: 575
# Associating photons to events:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-29 15:13:56,849 - Before grouping: 62 photons with non-NaN assoc_x
# 2026-01-29 15:13:56,852 - After grouping: 62 photons with non-NaN assoc_event_id
# ✅ Matched 62 of 63 photons (98.4%)
# ✅ Saved 1000 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 0.05 MB
#    Columns: 19
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">7 / 1,000</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.7%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">4 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">6.3%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">62 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.4%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">54 / 54</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.1%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_ml.associated_df.dropna()
# Out:
#       px/x   px/y    px/toa  px/tot        px/tof  ph/id    ph/x    ph/y  \
# 479  111.0  130.0  0.000010     1.0  3.406250e-07   20.0  112.65  130.90
# 490  111.0  131.0  0.000010     1.0  3.406250e-07   20.0  112.65  130.90
# 552  114.0  130.0  0.000010     1.0  3.406250e-07   20.0  112.65  130.90
# 856  130.0  134.0  0.000021     7.0  5.140625e-07   51.0  129.67  132.67
# 858  129.0  134.0  0.000021     7.0  5.140625e-07   51.0  129.67  132.67
# 859  131.0  134.0  0.000021     7.0  5.140625e-07   44.0  132.12  133.22
# 943  143.0  133.0  0.000021     1.0  5.625000e-07   52.0  144.69  134.06
#
#        ph/toa    ph/cog  ml_confidence  ev/id    ev/x    ev/y    ev/toa  ev/n  \
# 479  0.000010  0.862329       0.560791   15.0  112.21  130.34  0.000010   2.0
# 490  0.000010  0.862329       0.517803   15.0  112.21  130.34  0.000010   2.0
# 552  0.000010  0.862329       0.522833   15.0  112.21  130.34  0.000010   2.0
# 856  0.000020  1.340821       0.520755   31.0  129.67  132.67  0.000020   1.0
# 858  0.000020  1.340821       0.633759   31.0  129.67  132.67  0.000020   1.0
# 859  0.000020  1.364844       0.607308   34.0  132.12  133.22  0.000020   1.0
# 943  0.000021  1.994919       0.505262   51.0  144.69  134.06  0.000021   1.0
#
#            ev/psd  ev/cog  ph/n
# 479  2.343750e-08   0.005     3
# 490  2.343750e-08   0.005     3
# 552  2.343750e-08   0.005     3
# 856  0.000000e+00   0.000     2
# 858  0.000000e+00   0.000     2
# 859  0.000000e+00   0.000     1
# 943  0.000000e+00   0.000     1

# %% [markdown]
# The ML method adds an `ml_confidence` column with prediction confidence:

# %%
assoc_ml.associated_df['ml_confidence'].describe()
# Out:
# count    7.000000
# mean     0.552644
# std      0.049998
# min      0.505262
# 25%      0.519279
# 50%      0.522833
# 75%      0.584049
# max      0.633759
# Name: ml_confidence, dtype: float64

# %% [markdown]
# ### Step 3: Save/Load Models
#
# Save the model for later use:

# %%
import joblib

# Save
joblib.dump(model, 'association_model.joblib')

# Load and use
loaded_model = joblib.load('association_model.joblib')

# %% [markdown]
# ---
# ## Compare Methods
#
# Compare association statistics across methods:

# %%
def get_stats(analyser):
    df = analyser.associated_df
    return {
        'pixels_matched': (df['ph/id'] >= 0).sum(),
        'pixels_total': len(df),
        'match_rate': (df['ph/id'] >= 0).mean() * 100,
        'cog_mean': df['ph/cog'].mean(),
        'cog_std': df['ph/cog'].std()
    }

pd.DataFrame({
    'Simple': get_stats(assoc_simple),
    'Mystic': get_stats(assoc_mystic),
    'ML': get_stats(assoc_ml)
}).T
# Out:
#         pixels_matched  pixels_total  match_rate  cog_mean   cog_std
# Simple           518.0        1000.0        51.8  0.413720  0.221503
# Mystic           523.0        1000.0        52.3  0.436650  0.260617
# ML                 7.0        1000.0         0.7  1.232627  0.414999

# %% [markdown]
# ---
# ## Visualize Results
#
# Compare CoG quality distributions:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for ax, (name, a) in zip(axes, [('Simple', assoc_simple), ('Mystic', assoc_mystic), ('ML', assoc_ml)]):
    cog = a.associated_df['ph/cog'].dropna()
    ax.hist(cog, bins=50, edgecolor='white', alpha=0.7)
    ax.axvline(cog.median(), color='red', linestyle='--', label=f'median={cog.median():.2f}')
    ax.set_xlabel('CoG Distance (px)')
    ax.set_title(name)
    ax.legend()

plt.tight_layout()

# %% [markdown]
# ---
# ## Feature Importance (ML)
#
# For Random Forest models, inspect feature importance:

# %%
feature_names = ['dist_norm', 'dx_norm', 'dy_norm', 'dt_norm', 'tot_norm',
                 'dist_centroid', 'tot_rel', 'cluster_size', 'pixel_order', 'abs_dt']

if hasattr(model, 'feature_importances_'):
    importance = pd.Series(model.feature_importances_, index=feature_names).sort_values()
    importance.plot.barh(figsize=(8, 4))
    plt.xlabel('Feature Importance')
    plt.tight_layout()

# %% [markdown]
# ---
# ## Tips
#
# **When to use each method:**
#
# | Method | Use Case |
# |--------|----------|
# | `simple` | Default choice, fast and accurate |
# | `kdtree` | Large datasets, same accuracy as simple |
# | `mystic` | Ambiguous associations, training data generation |
# | `ml` | Fast inference after training, large datasets |
#
# **Training recommendations:**
# - Use `mystic` method for training labels (higher quality)
# - Train on representative data (similar conditions to inference)
# - Use at least 10,000 samples for good generalization
