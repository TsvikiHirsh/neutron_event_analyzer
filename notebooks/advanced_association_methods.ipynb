# %% [markdown]
# # Advanced Association Methods
#
# This notebook demonstrates the advanced pixel-to-photon association methods:
#
# 1. **Mystic** - Constrained optimization using the mystic framework
# 2. **ML** - Machine learning trained on constrained associations
#
# Both methods implement the verified EMPIR algorithm:
# - ToT-weighted center of gravity
# - Euclidean distance metric
# - Time window filtering

# %% [markdown]
# ## Setup

# %%
import neutron_event_analyzer as nea
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data
#
# Load a dataset with pixels, photons, and events. Adjust the path to your data folder.

# %%
data_path = "/work/nuclear/PTB/archive/pencilbeam0/fast_neutrons"

assoc = nea.Analyse(
    data_path,
    pixels=True,
    photons=True,
    events=True,
    limit=10000
)
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.

# %% [markdown]
# Check the loaded data:

# %%
assoc.pixels_df.shape, assoc.photons_df.shape, assoc.events_df.shape
# Out:
# ((10000, 5), (600, 4), (517, 6))

# %% [markdown]
# ---
# ## Method 1: Simple Association (Baseline)
#
# The default method uses a forward time-window with ToT-weighted center of gravity matching.

# %%
assoc_simple = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=1000)
assoc_simple.associate(method='simple')
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons:   0%|          | 0/63 [00:00<?, ?it/s]
# Associating photons to events:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-29 16:03:03,961 - Before grouping: 62 photons with non-NaN assoc_x
# 2026-01-29 16:03:03,964 - After grouping: 62 photons with non-NaN assoc_event_id
# ✅ Matched 62 of 63 photons (98.4%)
# ✅ Saved 1000 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 0.09 MB
#    Columns: 18
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">518 / 1,000</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">51.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">61 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">96.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">62 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.4%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">54 / 54</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">4.9%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">65.6%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.1%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_simple.associated_df.head()
# Out:
#     px/x   px/y  px/toa  px/tot  px/tof  ph/id    ph/x    ph/y  ph/toa  \
# 0  128.0  132.0     0.0     1.0     NaN    NaN     NaN     NaN     NaN
# 1  134.0  132.0     0.0     1.0     NaN    1.0  133.78  131.73     0.0
# 2  135.0  132.0     0.0     1.0     NaN    1.0  133.78  131.73     0.0
# 3  127.0  124.0     0.0     2.0     NaN    NaN     NaN     NaN     NaN
# 4  136.0  130.0     0.0     4.0     NaN    4.0  135.88  130.12     0.0
#
#      ph/cog  ev/id    ev/x    ev/y  ev/toa  ev/n  ev/psd  ev/cog  ph/n
# 0       NaN    NaN     NaN     NaN     NaN   NaN     NaN     NaN     0
# 1  0.338983   37.0  133.78  131.73     0.0   1.0     0.0     0.0    13
# 2  0.338983   37.0  133.78  131.73     0.0   1.0     0.0     0.0    13
# 3       NaN    NaN     NaN     NaN     NaN   NaN     NaN     NaN     0
# 4  0.169706   40.0  135.88  130.12     0.0   1.0     0.0     0.0     9

# %% [markdown]
# ---
# ## Method 2: Mystic Optimization
#
# The mystic method formulates association as a constrained optimization problem:
#
# - **Objective**: Minimize CoG distance + time penalty
# - **Constraints**: Minimum pixel count, spatial/temporal bounds
# - **Solver**: Powell's method or differential evolution
#
# This method is slower but can find better associations in ambiguous cases.

# %%
assoc_mystic = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=10000)
assoc_mystic.associate(method='mystic')
# Out:
# 📂 Auto-loaded association results: 1,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons (mystic):   0%|          | 0/600 [00:00<?, ?it/s]
# ✅ Pixel-Photon Association (mystic optimization):
#    Pixels:  5,183 / 10,000 matched (51.8%)
#    Photons: 594 / 600 matched (99.0%)
#    Optimization: 587 success, 7 fallback, 0 failed
# Associating photons to events (mystic):   0%|          | 0/517 [00:00<?, ?it/s]
# ✅ Photon-Event Association (mystic optimization):
#    Photons: 596 / 600 matched (99.3%)
#    Events:  516 / 517 matched (99.8%)
#    Optimization: 75 success, 441 fallback, 0 failed
# ✅ Saved 10000 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 0.99 MB
#    Columns: 18
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">5,183 / 10,000</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">51.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">594 / 600</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">99.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">62 / 63</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.4%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">54 / 54</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">7.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">68.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">98.1%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_mystic.associated_df.head()
# Out:
#     px/x   px/y  px/toa  px/tot  px/tof  ph/id   ph/x   ph/y  ph/toa  \
# 0  129.0  126.0     0.0     1.0     NaN    NaN    NaN    NaN     NaN
# 1  134.0  126.0     0.0     1.0     NaN    NaN    NaN    NaN     NaN
# 2  127.0  126.0     0.0     5.0     NaN    4.0  126.0  127.0     0.0
# 3  128.0  126.0     0.0     1.0     NaN    NaN    NaN    NaN     NaN
# 4  128.0  132.0     0.0     1.0     NaN    NaN    NaN    NaN     NaN
#
#      ph/cog  ev/id   ev/x   ev/y  ev/toa  ev/n  ev/psd  ev/cog  ph/n
# 0       NaN    NaN    NaN    NaN     NaN   NaN     NaN     NaN     0
# 1       NaN    NaN    NaN    NaN     NaN   NaN     NaN     NaN     0
# 2  0.870651    6.0  126.0  127.0     0.0   1.0     0.0     0.0     9
# 3       NaN    NaN    NaN    NaN     NaN   NaN     NaN     NaN     0
# 4       NaN    NaN    NaN    NaN     NaN   NaN     NaN     NaN     0

# %% [markdown]
# ---
# ## Method 3: ML-Based Association
#
# The ML method uses a trained classifier to predict pixel-to-photon associations.
#
# ### Step 1: Train the Model
#
# Train on constrained associations from mystic or simple method:

# %%
# Train on mystic-constrained associations
trainer = nea.Analyse(data_path, pixels=True, photons=True, events=True, limit=50000)

model = trainer.train_association_model(
    method='mystic',      # Use simple/mystic/kdtree for training labels
    model_type='mlp',      # rf, gb, mlp, or torch
    n_samples=20000
)
# Out:
# 📂 Auto-loaded association results: 10,000 rows
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Generating training data using 'mystic' method...
# Generating training data:   0%|          | 0/3093 [00:00<?, ?it/s]
# Training mlp model on 11,505 samples...
#    Positive samples: 6,097 (53.0%)
#    Negative samples: 5,408 (47.0%)
#    Training accuracy: 71.8%
#    Training F1 score: 0.732
#    Model auto-saved to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/ml_association_model.joblib

# %% [markdown]
# Available model types:
#
# | Type | Description |
# |------|-------------|
# | `rf` | Random Forest (fast, good default) |
# | `gb` | Gradient Boosting (slower, often better) |
# | `mlp` | Neural Network (sklearn MLP) |
# | `torch` | PyTorch Neural Network |

# %% [markdown]
# ### Step 2: Use the Trained Model

# %%
model
# Out:
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)

# %%
assoc_ml = nea.Analyse(data_path, pixels=True, photons=True, events=True)
assoc_ml.associate(method='ml')
# Out:
# 📂 Auto-loaded association results: 10,000 rows
# 📂 Auto-loaded ML model from: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/ml_association_model.joblib
# 📥 Loading raw data for re-analysis...
# Loading event-photon pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# Loading pixels:   0%|          | 0/20 [00:00<?, ?it/s]
# Loaded 154347 pixels in total.
# Associating pixels to photons (ML):   0%|          | 0/9412 [00:00<?, ?it/s]
# ✅ Pixel-Photon Association (ML):
#    Pixels:  42,183 / 154,347 matched (27.3%)
#    Photons: 9,123 / 9,412 matched (96.9%)
#    ML predictions made: 84,398
# Associating photons to events:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-01-29 16:13:28,397 - Before grouping: 9376 photons with non-NaN assoc_x
# 2026-01-29 16:13:28,402 - After grouping: 9376 photons with non-NaN assoc_event_id
# ✅ Matched 9376 of 9412 photons (99.6%)
# ✅ Saved 154347 rows to /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#    File size: 13.01 MB
#    Columns: 19
# 💾 Auto-saved results to: /work/nuclear/PTB/archive/pencilbeam0/fast_neutrons/AssociatedResults/associated_data.csv
#         <div style="font-family: Arial, sans-serif; font-size: 0.85em;">
#             <table style="border-collapse: collapse; border: 1px solid #ddd; table-layout: auto;">
#                 <thead>
#                     <!-- Top level headers (category grouping) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #ddd;">
#                         <th rowspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold; white-space: nowrap;">Group</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Pixel → Photon</th>
#                         <th colspan="4" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">Photon → Event</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (px2ph)</th>
#                         <th colspan="2" style="padding: 8px; border: 1px solid #ddd; text-align: center; font-weight: bold; border-bottom: 1px solid #999;">CoM Quality (ph2ev)</th>
#                     </tr>
#                     <!-- Second level headers (specific metrics) -->
#                     <tr style="background-color: white; border-bottom: 2px solid #444;">
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pixels</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Pix %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Photons</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Phot %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Events</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Evt %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Exact %</th>
#                         <th style="padding: 6px; border: 1px solid #ddd; text-align: center; font-weight: bold; font-size: 0.9em;">Good %</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr style="background-color: white;">
#                         <td style="padding: 8px; border: 1px solid #ddd; white-space: nowrap;"><strong>fast_neutrons</strong></td>
#             <td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">42,183 / 154,347</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">27.3%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">9,123 / 9,412</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">96.9%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">9,376 / 9,412</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">99.6%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; font-size: 0.9em;">8,206 / 8,206</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">100.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">3.0%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #FFA500; font-size: 0.9em;">51.5%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: #90EE90; font-size: 0.9em;">99.8%</td><td style="padding: 6px; border: 1px solid #ddd; text-align: center; background-color: indianred; font-size: 0.9em;">0.0%</td>
#                     </tr>
#
#                 </tbody>
#             </table>
#         </div>

# %%
assoc_ml.associated_df.dropna()
# Out:
#          px/x   px/y        px/toa  px/tot        px/tof   ph/id    ph/x  \
# 131     126.0  131.0  4.218750e-07     1.0  4.218750e-07     7.0  125.60
# 132     125.0  131.0  4.218750e-07     1.0  4.218750e-07     7.0  125.60
# 144     125.0  128.0  4.218750e-07     1.0  4.218750e-07     7.0  125.60
# 148     127.0  127.0  4.218750e-07     2.0  4.218750e-07     8.0  126.73
# 149     126.0  127.0  4.218750e-07     2.0  4.218750e-07     8.0  126.73
# ...       ...    ...           ...     ...           ...     ...     ...
# 154334  217.0   31.0  6.940434e-03     9.0  4.343750e-07  9407.0  216.80
# 154335  214.0   31.0  6.940434e-03     1.0  4.343750e-07  9411.0  213.00
# 154336  215.0   32.0  6.940434e-03     1.0  4.343750e-07  9411.0  213.00
# 154342  208.0   32.0  6.940434e-03     1.0  4.343750e-07  9408.0  208.57
# 154346  213.0   28.0  6.940434e-03     1.0  4.343750e-07  9409.0  213.07
#
#           ph/y        ph/toa    ph/cog  ml_confidence   ev/id    ev/x    ev/y  \
# 131     129.14  4.218750e-07  0.217664       0.769823  3141.0  125.60  129.14
# 132     129.14  4.218750e-07  0.217664       0.829977  3141.0  125.60  129.14
# 144     129.14  4.218750e-07  0.217664       0.501702  3141.0  125.60  129.14
# 148     125.92  4.218750e-07  0.448414       0.638921  3722.0  127.67  125.46
# 149     125.92  4.218750e-07  0.448414       0.542235  3722.0  127.67  125.46
# ...        ...           ...       ...            ...     ...     ...     ...
# 154334   29.80  6.940412e-03  0.597430       0.999487  7918.0  216.80   29.80
# 154335   32.00  6.940434e-03  0.353553       0.820028  7866.0  212.82   32.67
# 154336   32.00  6.940434e-03  0.353553       0.597889  7866.0  212.82   32.67
# 154342   30.37  6.940412e-03  0.144439       0.542934  7792.0  208.57   30.37
# 154346   26.73  6.940434e-03  0.220039       0.537581  7870.0  213.07   26.73
#
#               ev/toa  ev/n        ev/psd  ev/cog  ph/n
# 131     4.218750e-07   1.0  0.000000e+00   0.000     7
# 132     4.218750e-07   1.0  0.000000e+00   0.000     7
# 144     4.218750e-07   1.0  0.000000e+00   0.000     7
# 148     4.218750e-07   2.0  0.000000e+00   0.005     7
# 149     4.218750e-07   2.0  0.000000e+00   0.005     7
# ...              ...   ...           ...     ...   ...
# 154334  6.940412e-03   1.0  0.000000e+00   0.000     4
# 154335  6.940412e-03   2.0  1.093750e-08   0.000     4
# 154336  6.940412e-03   2.0  1.093750e-08   0.000     4
# 154342  6.940412e-03   1.0  0.000000e+00   0.000    10
# 154346  6.940434e-03   1.0  0.000000e+00   0.000     8
#
# [42040 rows x 19 columns]

# %% [markdown]
# The ML method adds an `ml_confidence` column with prediction confidence:

# %%
assoc_ml.associated_df['ml_confidence'].describe()
# Out:
# count    42183.000000
# mean         0.708599
# std          0.134380
# min          0.500005
# 25%          0.595429
# 50%          0.696365
# 75%          0.803236
# max          0.999962
# Name: ml_confidence, dtype: float64

# %% [markdown]
# ### Step 3: Save/Load Models
#
# Save the model for later use:

# %%
import joblib

# Save
joblib.dump(model, 'association_model.joblib')

# Load and use
loaded_model = joblib.load('association_model.joblib')

# %% [markdown]
# ---
# ## Compare Methods
#
# Compare association statistics across methods:

# %%
def get_stats(analyser):
    df = analyser.associated_df
    return {
        'pixels_matched': (df['ph/id'] >= 0).sum(),
        'pixels_total': len(df),
        'match_rate': (df['ph/id'] >= 0).mean() * 100,
        'cog_mean': df['ph/cog'].mean(),
        'cog_std': df['ph/cog'].std()
    }

pd.DataFrame({
    'Simple': get_stats(assoc_simple),
    'Mystic': get_stats(assoc_mystic),
    'ML': get_stats(assoc_ml)
}).T
# Out:
#         pixels_matched  pixels_total  match_rate  cog_mean   cog_std
# Simple           518.0        1000.0   51.800000  0.411300  0.221140
# Mystic          5183.0       10000.0   51.830000  0.382796  0.257938
# ML             42183.0      154347.0   27.329977  0.536144  0.322841

# %% [markdown]
# ---
# ## Visualize Results
#
# Compare CoG quality distributions:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for ax, (name, a) in zip(axes, [('Simple', assoc_simple), ('Mystic', assoc_mystic), ('ML', assoc_ml)]):
    cog = a.associated_df['ph/cog'].dropna()
    ax.hist(cog, bins=50, edgecolor='white', alpha=0.7)
    ax.axvline(cog.median(), color='red', linestyle='--', label=f'median={cog.median():.2f}')
    ax.set_xlabel('CoG Distance (px)')
    ax.set_title(name)
    ax.legend()

plt.tight_layout()

# %% [markdown]
# ---
# ## Feature Importance (ML)
#
# For Random Forest models, inspect feature importance:

# %%
feature_names = ['dist_norm', 'dx_norm', 'dy_norm', 'dt_norm', 'tot_norm',
                 'dist_centroid', 'tot_rel', 'cluster_size', 'abs_dt']

if hasattr(model, 'feature_importances_'):
    importance = pd.Series(model.feature_importances_, index=feature_names).sort_values()
    importance.plot.barh(figsize=(8, 4))
    plt.xlabel('Feature Importance')
    plt.tight_layout()

# %% [markdown]
# ---
# ## Tips
#
# **When to use each method:**
#
# | Method | Use Case |
# |--------|----------|
# | `simple` | Default choice, fast and accurate |
# | `kdtree` | Large datasets, same accuracy as simple |
# | `mystic` | Ambiguous associations, training data generation |
# | `ml` | Fast inference after training, large datasets |
#
# **Training recommendations:**
# - Use `mystic` method for training labels (higher quality)
# - Train on representative data (similar conditions to inference)
# - Use at least 10,000 samples for good generalization
